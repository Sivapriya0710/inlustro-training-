# %% [markdown]
# <a href="https://colab.research.google.com/github/Sivapriya0710/inlustro-training-/blob/main/NLP_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer,LancasterStemmer,SnowballStemmer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
from nltk.corpus import stopwords


nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
text="She is dancing well"
tokens=word_tokenize(text)
print("Original tokens:",tokens)
# Out:
# Original tokens: ['She', 'is', 'dancing', 'well']

# %%
porter = PorterStemmer()
stemmed_words=[porter.stem(word)for word in tokens]
print("Porter Stemmer:",stemmed_words)
# Out:
# Porter Stemmer: ['she', 'is', 'danc', 'well']

# %%
lemmatizer=WordNetLemmatizer()
lemmatizer_words=[lemmatizer.lemmatize(word) for word in tokens]
print("Lemmatized Words:", lemmatizer_words)
# Out:
# Lemmatized Words: ['She', 'is', 'dancing', 'well']

# %%
tokens=[word.lower()for word in tokens]
print("Lowercased Tokens:",tokens)
# Out:
# Lowercased Tokens: ['she', 'is', 'dancing', 'well']

# %%
default_stopword=set(stopwords.words('english'))
default_filtered_tokens=[word for word in tokens if word not in default_stopword]
print("Tokens after removing default stopwords:", default_filtered_tokens)
# Out:
# Tokens after removing default stopwords: ['dancing', 'well']

# %%
# Removing custom stopwords
custom_stopwords={"striped","bats","."}
custom_filtered_tokens = [word for word in default_filtered_tokens if word not in custom_stopwords]
print("Tokens after removing custom stopwords:", custom_filtered_tokens)
# Out:
# Tokens after removing custom stopwords: ['dancing', 'well']

# %%
from nltk import pos_tag
nltk.download('averaged_perceptron_tagger_eng')
pos_tags = pos_tag(custom_filtered_tokens)
print("POS Tags:",pos_tags)
# Out:
# POS Tags: [('dancing', 'VBG'), ('well', 'RB')]
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
