# %% [markdown]
# <a href="https://colab.research.google.com/github/Sivapriya0710/inlustro-training-/blob/main/LLMS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from diffusers import StableDiffusionPipeline
import torch
pipe = StableDiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5")
pipe.to("cpu")
prompt = "A futuristic city skyline at sunset"
image = pipe(prompt).images[0]
image.show()
image.save("generated_image.png")

# %%
from google.generativeai import GenerativeModel,configure
configure (api_key="AIzaSyD3erP9ziHIfB_1zZXe3LFbdzVVDgiqHOw")
model = GenerativeModel("gemini-1.5-pro")
r = model.generate_content("who are you?")
print(r.text)
# Out:
# I am a large language model, trained by Google.

# %%
from google.generativeai import GenerativeModel, configure
configure(api_key="AIzaSyD3erP9ziHIfB_1zZXe3LFbdzVVDgiqHOw")
model = GenerativeModel("gemini-1.5-pro")
print("Welcome to AI chatpot! Type 'exit' to stop.")
while True:
    user_input = input("You: ")
    if user_input.lower() == "exit":
       break
    response = model.generate_content(user_input)
    print("AI:", response.text)
# Out:
# Welcome to AI chatpot! Type 'exit' to stop.
# You: Hello
# AI: Hello there! How can I help you today?
#
# You: "Top five actor name"
# AI: There's no single objective "top five" list of actors, as it depends entirely on criteria like box office success, awards, critical acclaim, or personal preference.  However, I can give you some names frequently cited as among the best or most influential:
#
# * **Marlon Brando:** Known for his method acting and roles in films like "A Streetcar Named Desire" and "The Godfather."
# * **Robert De Niro:**  Highly regarded for his versatility and collaborations with Martin Scorsese, including "Taxi Driver" and "Raging Bull."
# * **Meryl Streep:** Holds the record for most Academy Award nominations and is celebrated for her transformative performances in films like "Sophie's Choice" and "Kramer vs. Kramer."
# * **Daniel Day-Lewis:** Known for his intense preparation and immersive method acting, starring in films like "There Will Be Blood" and "Lincoln."
# * **Jack Nicholson:** Celebrated for his charismatic and often eccentric portrayals in films like "One Flew Over the Cuckoo's Nest" and "The Shining."
#
# This is just a starting point, and many other actors could be included.  To get a better answer, it's helpful to specify what you consider "top" to mean.
#
# You: "what is your name"
# AI: I don't have a name. I'm a large language model, an AI.
#
# You: Ok
# AI: Ok.  Is there anything I can help you with?
#
# You: "How are you AI"
# AI: I'm doing well, thank you for asking!  As a large language model, I don't experience emotions or feelings like humans do.  However, I'm functioning as designed and ready to assist you. How can I help you today?
#
# You: Ok
# AI: Ok.  Is there anything I can help you with?
#
# You: Exit

# %%
pip install deep_translator
# Out:
# Collecting deep_translator
#   Downloading deep_translator-1.11.4-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in /usr/local/lib/python3.11/dist-packages (from deep_translator) (4.13.3)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from deep_translator) (2.32.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep_translator) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep_translator) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (2025.1.31)
# Downloading deep_translator-1.11.4-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 2.5 MB/s eta 0:00:00
# Installing collected packages: deep_translator
# Successfully installed deep_translator-1.11.4

# %%
from deep_translator import GoogleTranslator
def translate_text(text, target_language):
    translator = GoogleTranslator(source='auto',target=target_language)
    return translator.translate(text)
text = "hi siva"
target_language = "fr"
translated_text = translate_text(text,target_language)
print(f"Original: {text}")
print(f"Translated ({target_language}):{translated_text}")
# Out:
# Original: hi siva
# Translated (fr):Salut Siva
